# %% [markdown]
# <a href="https://colab.research.google.com/github/victorvargas1108/Modulo4_MineriaDatos/blob/master/Practica1_Datos_Agro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Práctica 1: Datos agro 2018

# %%
import numpy as np

# %%
import missingno as msno

# %%
path = 'Datos_agro_enigh_2018_ns.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri   ero_tri
# 0  100317506         1       1  ...   19565.21       0.00  19563.26
# 1  100317506         1       1  ...   95624.99   26656.63      0.00
# 2  100961704         1       1  ...   12295.08       0.00  12293.11
# 3  100961704         1       1  ...   82696.72  574025.90      0.00
# 4  101917906         1       1  ...      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
# General Stats
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14925 entries, 0 to 14924
# Data columns (total 56 columns):
# folioviv      14925 non-null int64
# foliohog      14925 non-null int64
# numren        14925 non-null int64
# id_trabajo    14925 non-null int64
# tipoact       14925 non-null int64
# cose_cria     14925 non-null int64
# prep_deriv    14925 non-null object
# otro_pago     14925 non-null int64
# fpago_1       14925 non-null object
# fpago_2       14925 non-null object
# fpago_3       14925 non-null object
# fpago_4       14925 non-null object
# fpago_5       14925 non-null object
# fpago_6       14925 non-null object
# fpago_7       14925 non-null object
# fpago_8       14925 non-null object
# nofpago       14925 non-null object
# t_emp         14925 non-null int64
# h_emp         14925 non-null object
# m_emp         14925 non-null object
# t_cpago       14925 non-null object
# h_cpago       14925 non-null object
# m_cpago       14925 non-null object
# t_ispago      14925 non-null object
# h_ispago      14925 non-null object
# m_ispago      14925 non-null object
# t_nispago     14925 non-null object
# h_nispago     14925 non-null object
# m_nispago     14925 non-null object
# valrema       14925 non-null object
# valproc       14925 non-null object
# apoyo         14925 non-null int64
# apoyo_1       14925 non-null object
# apoyo_2       14925 non-null object
# apoyo_3       14925 non-null object
# apoyo_4       14925 non-null object
# apoyo_5       14925 non-null object
# apoyo_6       14925 non-null object
# apoyo_7       14925 non-null object
# apoyo_8       14925 non-null object
# procampo      14925 non-null object
# mesproc       14925 non-null object
# progan        14925 non-null object
# mesprogan     14925 non-null object
# reg_not       14925 non-null int64
# reg_cont      14925 non-null int64
# ventas        14925 non-null int64
# autocons      14925 non-null int64
# otrosnom      14925 non-null int64
# gasneg        14925 non-null int64
# ventas_tri    14925 non-null float64
# auto_tri      14925 non-null float64
# otros_tri     14925 non-null float64
# gasto_tri     14925 non-null float64
# ing_tri       14925 non-null float64
# ero_tri       14925 non-null float64
# dtypes: float64(6), int64(15), object(35)
# memory usage: 6.4+ MB

# %%
df.shape
# Out:
# (14925, 56)

# %%
df.shape[0]
# Out:
# 14925

# %%
df.shape[1]
# Out:
# 56

# %%
df.columns.values.tolist()
# Out:
# ['folioviv',
#  'foliohog',
#  'numren',
#  'id_trabajo',
#  'tipoact',
#  'cose_cria',
#  'prep_deriv',
#  'otro_pago',
#  'fpago_1',
#  'fpago_2',
#  'fpago_3',
#  'fpago_4',
#  'fpago_5',
#  'fpago_6',
#  'fpago_7',
#  'fpago_8',
#  'nofpago',
#  't_emp',
#  'h_emp',
#  'm_emp',
#  't_cpago',
#  'h_cpago',
#  'm_cpago',
#  't_ispago',
#  'h_ispago',
#  'm_ispago',
#  't_nispago',
#  'h_nispago',
#  'm_nispago',
#  'valrema',
#  'valproc',
#  'apoyo',
#  'apoyo_1',
#  'apoyo_2',
#  'apoyo_3',
#  'apoyo_4',
#  'apoyo_5',
#  'apoyo_6',
#  'apoyo_7',
#  'apoyo_8',
#  'procampo',
#  'mesproc',
#  'progan',
#  'mesprogan',
#  'reg_not',
#  'reg_cont',
#  'ventas',
#  'autocons',
#  'otrosnom',
#  'gasneg',
#  'ventas_tri',
#  'auto_tri',
#  'otros_tri',
#  'gasto_tri',
#  'ing_tri',
#  'ero_tri']

# %%
df.dtypes
# Out:
# folioviv        int64
# foliohog        int64
# numren          int64
# id_trabajo      int64
# tipoact         int64
# cose_cria       int64
# prep_deriv     object
# otro_pago       int64
# fpago_1        object
# fpago_2        object
# fpago_3        object
# fpago_4        object
# fpago_5        object
# fpago_6        object
# fpago_7        object
# fpago_8        object
# nofpago        object
# t_emp           int64
# h_emp          object
# m_emp          object
# t_cpago        object
# h_cpago        object
# m_cpago        object
# t_ispago       object
# h_ispago       object
# m_ispago       object
# t_nispago      object
# h_nispago      object
# m_nispago      object
# valrema        object
# valproc        object
# apoyo           int64
# apoyo_1        object
# apoyo_2        object
# apoyo_3        object
# apoyo_4        object
# apoyo_5        object
# apoyo_6        object
# apoyo_7        object
# apoyo_8        object
# procampo       object
# mesproc        object
# progan         object
# mesprogan      object
# reg_not         int64
# reg_cont        int64
# ventas          int64
# autocons        int64
# otrosnom        int64
# gasneg          int64
# ventas_tri    float64
# auto_tri      float64
# otros_tri     float64
# gasto_tri     float64
# ing_tri       float64
# ero_tri       float64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['prep_deriv',
#  'fpago_1',
#  'fpago_2',
#  'fpago_3',
#  'fpago_4',
#  'fpago_5',
#  'fpago_6',
#  'fpago_7',
#  'fpago_8',
#  'nofpago',
#  'h_emp',
#  'm_emp',
#  't_cpago',
#  'h_cpago',
#  'm_cpago',
#  't_ispago',
#  'h_ispago',
#  'm_ispago',
#  't_nispago',
#  'h_nispago',
#  'm_nispago',
#  'valrema',
#  'valproc',
#  'apoyo_1',
#  'apoyo_2',
#  'apoyo_3',
#  'apoyo_4',
#  'apoyo_5',
#  'apoyo_6',
#  'apoyo_7',
#  'apoyo_8',
#  'procampo',
#  'mesproc',
#  'progan',
#  'mesprogan']

# %%
df.describe()
# Out:
#            folioviv      foliohog  ...       ing_tri        ero_tri
# count  1.492500e+04  14925.000000  ...  1.492500e+04   14925.000000
# mean   1.841456e+09      1.004958  ...  3.813851e+03     719.248916
# std    8.765220e+08      0.072124  ...  1.924913e+04    5893.089901
# min    1.003175e+08      1.000000  ...  0.000000e+00       0.000000
# 25%    1.161174e+09      1.000000  ...  0.000000e+00       0.000000
# 50%    1.860410e+09      1.000000  ...  6.016300e+02       0.000000
# 75%    2.560551e+09      1.000000  ...  2.444670e+03       0.000000
# max    3.260799e+09      3.000000  ...  1.223700e+06  297132.060000
#
# [8 rows x 21 columns]

# %%
df.loc[[0]]
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri  ing_tri   ero_tri
# 0  100317506         1       1  ...   19565.21      0.0  19563.26
#
# [1 rows x 56 columns]

# %%
df.loc[30:33]
# Out:
#      folioviv  foliohog  numren  ...  gasto_tri    ing_tri  ero_tri
# 30  160006216         1       1  ...  107403.31  135301.32     0.00
# 31  160006520         1       1  ...    8804.34    9781.63     0.00
# 32  160006524         1       7  ...    2201.08       0.00  2201.08
# 33  160006524         1       7  ...    7630.43   14359.89     0.00
#
# [4 rows x 56 columns]

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#      folioviv  foliohog  numren  ...  gasto_tri  ing_tri   ero_tri
# 0   100317506         1       1  ...   19565.21     0.00  19563.26
# 5   101998619         1       1  ...     245.90     0.00    244.91
# 6   101998619         1       1  ...      49.18  4376.06      0.00
# 7   101998802         1       1  ...    6946.72   427.86      0.00
# 8   102022605         1       1  ...   16155.73     0.00   3552.78
# 9   102041503         1       1  ...      73.36     0.00     73.36
# 10  102110402         1       2  ...     254.34  7997.28      0.00
# 11  102126212         1       1  ...      79.06   143.20      0.00
# 12  102137224         1       1  ...    2371.82     0.00    107.40
# 13  102137224         1       1  ...     149.17  1715.46      0.00
#
# [10 rows x 56 columns]

# %%
df[100:].head() #df.tail(-100) )
# Out:
#       folioviv  foliohog  numren  ...  gasto_tri   ing_tri  ero_tri
# 100  160215510         1       1  ...   14184.78  22424.67      0.0
# 101  160229801         1       3  ...    7377.04   3440.65      0.0
# 102  160229801         1       3  ...    7180.32   1788.19      0.0
# 103  160229803         1       1  ...    3590.16   6158.36      0.0
# 104  160229803         1       1  ...    8950.81  21172.13      0.0
#
# [5 rows x 56 columns]

# %%
df.apoyo.values
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
df['apoyo'].values
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
df.apoyo.unique()
# Out:
# array([2, 1])

# %%
df.apoyo.value_counts()
# Out:
# 2    13789
# 1     1136
# Name: apoyo, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri  ing_tri  ero_tri
# count       14925     14925   14925  ...      14925    14925    14925
# size        14925     14925   14925  ...      14925    14925    14925
# nunique     10159         3      11  ...       4941     4781     1763
#
# [3 rows x 56 columns]

# %%
df.groupby('apoyo').agg(['count', 'size', 'nunique']).stack()
# Out:
#                folioviv  foliohog  numren  ...  gasto_tri  ing_tri  ero_tri
# apoyo                                      ...
# 1     count        1136      1136    1136  ...       1136     1136     1136
#       size         1136      1136    1136  ...       1136     1136     1136
#       nunique      1084         2       9  ...        855      766      270
# 2     count       13789     13789   13789  ...      13789    13789    13789
#       size        13789     13789   13789  ...      13789    13789    13789
#       nunique      9642         3      11  ...       4564     4489     1623
#
# [6 rows x 55 columns]

# %%
df.groupby('apoyo').agg(['count', 'size', 'nunique'])
# Out:
#       folioviv                foliohog  ... ing_tri ero_tri
#          count   size nunique    count  ... nunique   count   size nunique
# apoyo                                   ...
# 1         1136   1136    1084     1136  ...     766    1136   1136     270
# 2        13789  13789    9642    13789  ...    4489   13789  13789    1623
#
# [2 rows x 165 columns]

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri   ing_tri  ero_tri
# 5633   1361341224         1       1  ...      74.58    122.32      0.0
# 3836   1161699824         1       1  ...     811.47  10566.88      0.0
# 13294  3063210319         1       1  ...     190.76    296.41      0.0
# 8423   2060964308         1       1  ...      85.59    340.43      0.0
# 9218   2062504406         1       3  ...    2064.13   5561.41      0.0
#
# [5 rows x 56 columns]

# %%
df.shape
# Out:
# (14925, 56)

# %%
df_sample.shape
# Out:
# (746, 56)

# %%
df_dropped = df.dropna(subset=['prep_deriv'])
df_dropped.head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri  ero_tri
# 1  100317506         1       1  ...   95624.99   26656.63     0.00
# 3  100961704         1       1  ...   82696.72  574025.90     0.00
# 6  101998619         1       1  ...      49.18    4376.06     0.00
# 7  101998802         1       1  ...    6946.72     427.86     0.00
# 9  102041503         1       1  ...      73.36       0.00    73.36
#
# [5 rows x 56 columns]

# %%
df_dropped.shape
# Out:
# (6996, 56)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri   ero_tri
# 0  100317506         1       1  ...   19565.21       0.00  19563.26
# 1  100317506         1       1  ...   95624.99   26656.63      0.00
# 2  100961704         1       1  ...   12295.08       0.00  12293.11
# 3  100961704         1       1  ...   82696.72  574025.90      0.00
# 4  101917906         1       1  ...      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
df_copy.shape
# Out:
# (14925, 56)

# %%
df_dropped['ventas'].dtype
# Out:
# dtype('int64')

# %%
df_dropped['ventas'].mean()
# Out:
# 20135.286878216124

# %%
df_copy['ventas'].fillna(value=np.round(df['ventas'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri  ing_tri  ero_tri
# count       14925     14925   14925  ...      14925    14925    14925
# size        14925     14925   14925  ...      14925    14925    14925
# nunique     10159         3      11  ...       4941     4781     1763
#
# [3 rows x 56 columns]

# %%
list(df['tipoact'].unique())
# Out:
# [4, 5, 7, 6, 9, 8]

# %%
"""
4 Actividades agrícolas
5 Actividades de cría y explotación de animales
6 Actividades de recolección
7 Reforestación y tala de árboles
8 Actividades de caza y captura de animales
9 Actividades de pesca
"""
df['tipoact'].replace({4:"agrícolas", 
                       5:"animales",
                       7:"recolección", 
                       6:"tala", 
                       9:"caza", 
                       8:"pesca"}, inplace=True)

# %%
list(df['tipoact'].unique())
# Out:
# ['agrícolas', 'animales', 'recolección', 'tala', 'caza', 'pesca']

# %%
keys = list(df['tipoact'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'agrícolas': 1,
#  'animales': 2,
#  'caza': 5,
#  'pesca': 6,
#  'recolección': 3,
#  'tala': 4}

# %%
df_copy['tipoact_cat'] = df['tipoact'].map(act)
df_copy.head()
# Out:
#     folioviv  foliohog  numren  ...    ing_tri   ero_tri  tipoact_cat
# 0  100317506         1       1  ...       0.00  19563.26            1
# 1  100317506         1       1  ...   26656.63      0.00            2
# 2  100961704         1       1  ...       0.00  12293.11            1
# 3  100961704         1       1  ...  574025.90      0.00            2
# 4  101917906         1       1  ...       0.00      8.80            3
#
# [5 rows x 57 columns]

# %%
list(df_copy['tipoact_cat'].unique())
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
df_copy['ventas'].mean()
# Out:
# 24930.588408710217

# %%
df_copy['ventas'][df_copy['tipoact'] == 6]
# Out:
# 10       32970
# 38       25680
# 223      10750
# 243      85834
# 399       5520
#          ...
# 14373    12960
# 14379    42593
# 14451    44500
# 14486     2625
# 14492     3780
# Name: ventas, Length: 261, dtype: int64

# %%
df_copy['ventas'][df_copy['tipoact_cat'] == 6].mean()
# Out:
# 2914.6666666666665

# %%
df_copy.groupby(["tipoact_cat", "cose_cria", "prep_deriv", "otro_pago"]).count()
# Out:
#                                             folioviv  ...  ero_tri
# tipoact_cat cose_cria prep_deriv otro_pago            ...
# 1           2         1          1                 1  ...        1
#                                  2                29  ...       29
#                       2          2                 9  ...        9
# 2           1         1          1                71  ...       71
#                                  2              4443  ...     4443
#                       2          1                86  ...       86
#                                  2              2357  ...     2357
#
# [7 rows x 53 columns]

# %%
df_copy.groupby(["tipoact_cat", "cose_cria", "prep_deriv", "otro_pago"]).count()
# Out:
#                                             folioviv  ...  ero_tri
# tipoact_cat cose_cria prep_deriv otro_pago            ...
# 1           2         1          1                 1  ...        1
#                                  2                29  ...       29
#                       2          2                 9  ...        9
# 2           1         1          1                71  ...       71
#                                  2              4443  ...     4443
#                       2          1                86  ...       86
#                                  2              2357  ...     2357
#
# [7 rows x 53 columns]

# %%
df_copy.groupby(["tipoact", "cose_cria"])[["prep_deriv", "otro_pago"]].count()
# Out:
#                    prep_deriv  otro_pago
# tipoact cose_cria
# 4       1                   0       7362
#         2                  39         39
# 5       1                6957       6957
#         2                   0          1
# 6       1                   0        261
# 7       1                   0         51
#         2                   0          1
# 8       1                   0          6
# 9       1                   0        247

# %%
df_copy.tipoact
# Out:
# 0        4
# 1        5
# 2        4
# 3        5
# 4        7
#         ..
# 14920    5
# 14921    4
# 14922    5
# 14923    4
# 14924    5
# Name: tipoact, Length: 14925, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri   ing_tri  ero_tri
# 5633   1361341224         1       1  ...      74.58    122.32      0.0
# 3836   1161699824         1       1  ...     811.47  10566.88      0.0
# 13294  3063210319         1       1  ...     190.76    296.41      0.0
# 8423   2060964308         1       1  ...      85.59    340.43      0.0
# 9218   2062504406         1       3  ...    2064.13   5561.41      0.0
#
# [5 rows x 56 columns]

# %%
# variant-1: multiple aggregations on single attribute
df_sample.groupby(["tipoact", "cose_cria"])[["prep_deriv", "otro_pago"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                       otro_pago
#                             sum      mean count_nonzero
# tipoact     cose_cria
# agrícolas   1               729  1.970270           370
#             2                 4  2.000000             2
# animales    1               686  1.971264           348
#             2                 2  2.000000             1
# caza        1                18  1.800000            10
# recolección 1                 2  2.000000             1
# tala        1                28  2.000000            14

# %%
# variant-2: different aggregation functions for each attribute 

df_sample.groupby(["tipoact", "cose_cria"]).agg({'ventas':np.mean,'otro_pago':np.max})
# Out:
#                               ventas  otro_pago
# tipoact     cose_cria
# agrícolas   1           23868.200000          2
#             2               0.000000          2
# animales    1           17341.959770          2
#             2               0.000000          2
# caza        1          108393.700000          2
# recolección 1            9000.000000          2
# tala        1           22991.285714          2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
#The equivalent of this command within the object-oriented interface is fig.add_axes()

fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
# plt.subplots_adjust can be used to adjust the spacing between these plots
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
#figure.savefig('.../.jpeg')
#df_sample['ventas'] = dropna()
df_sample['ventas'] = df_sample['ventas'].astype('int64')
df_sample.plot(kind='scatter',x='ventas',y='tipoact')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-454535fe3af6> in <module>()
#       1 df_sample['ventas'] = df_sample['ventas'].astype('int64')
# ----> 2 df_sample.plot(kind='scatter',x='ventas',y='tipoact')
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      62     plot_obj.generate()
#      63     plot_obj.draw()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, s, c, **kwargs)
#     928             # the handling of this argument later
#     929             s = 20
# --> 930         super().__init__(data, x, y, s=s, **kwargs)
#     931         if is_integer(c) and not self.data.columns.holds_integer():
#     932             c = self.data.columns[c]
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, **kwargs)
#     870             raise ValueError(self._kind + " requires x column to be numeric")
#     871         if len(self.data[y]._get_numeric_data()) == 0:
# --> 872             raise ValueError(self._kind + " requires y column to be numeric")
#     873
#     874         self.x = x
#
# ValueError: scatter requires y column to be numeric

# %%
plt.hist(df_sample['tipoact'])
plt.xlabel('tipoact')
plt.ylabel('Frequency')
plt.title('Frequency of tipoact')
# Out:
# Text(0.5, 1.0, 'Frequency of tipoact')

# %%
plt.hist(df_sample['ventas'])
plt.xlabel('ventas')
plt.ylabel('Frequency')
plt.title('Frequency of ventas')
# Out:
# Text(0.5, 1.0, 'Frequency of ventas')

# %%
#plt.boxplot(df_sample['ventas'])
plt.boxplot(df_sample['ventas'], showmeans=True, meanline=True)
plt.ylabel('ventas count')
plt.title('Box Plot of ventas count')
# Out:
# Text(0.5, 1.0, 'Box Plot of ventas count')
